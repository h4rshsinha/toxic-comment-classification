# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn import metrics
import string
import spacy
np.random.seed(42)

# %%
data=pd.read_csv('./youtoxic_english_1000.csv')
data.head()
# Out:
#               CommentId      VideoId  \
# 0  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
#
#                                                 Text  IsToxic  IsAbusive  \
# 0  If only people would just take a step back and...    False      False
# 1  Law enforcement is not trained to shoot to app...     True       True
# 2  \nDont you reckon them 'black lives matter' ba...     True       True
# 3  There are a very large number of people who do...    False      False
# 4  The Arab dude is absolutely right, he should h...    False      False
#
#    IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  IsNationalist  \
# 0     False          False      False         False     False          False
# 1     False          False      False         False     False          False
# 2     False          False       True         False     False          False
# 3     False          False      False         False     False          False
# 4     False          False      False         False     False          False
#
#    IsSexist  IsHomophobic  IsReligiousHate  IsRadicalism
# 0     False         False            False         False
# 1     False         False            False         False
# 2     False         False            False         False
# 3     False         False            False         False
# 4     False         False            False         False

# %%
data['IsToxic']=data['IsToxic'].astype('int')

# %%
data.head()
# Out:
#               CommentId      VideoId  \
# 0  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
#
#                                                 Text  IsToxic  IsAbusive  \
# 0  If only people would just take a step back and...        0      False
# 1  Law enforcement is not trained to shoot to app...        1       True
# 2  \nDont you reckon them 'black lives matter' ba...        1       True
# 3  There are a very large number of people who do...        0      False
# 4  The Arab dude is absolutely right, he should h...        0      False
#
#    IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  IsNationalist  \
# 0     False          False      False         False     False          False
# 1     False          False      False         False     False          False
# 2     False          False       True         False     False          False
# 3     False          False      False         False     False          False
# 4     False          False      False         False     False          False
#
#    IsSexist  IsHomophobic  IsReligiousHate  IsRadicalism
# 0     False         False            False         False
# 1     False         False            False         False
# 2     False         False            False         False
# 3     False         False            False         False
# 4     False         False            False         False

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = nlp.Defaults.stop_words
print(stop_words)
# Out:
# {'in', "'re", 'six', 'she', 're', 'there', 'an', 'he', 'seem', 'every', 'nobody', 'thru', 'whoever', 'each', 'both', 'nor', 'did', 'throughout', 'here', 'already', 'still', 'back', 'everywhere', 'otherwise', 'you', 'now', "'ve", 'over', 'becomes', 'after', 'noone', 'would', 'around', 'among', 'none', 'hereupon', 'it', 'side', 'yourselves', 'amongst', 'top', 'between', 'before', 'such', 'part', 'will', 'been', 'themselves', 'most', 'ten', 'thereafter', 'all', 'seeming', 'besides', 'get', 'nowhere', 'quite', 'that', 'unless', 'anywhere', 'formerly', 'if', 'yet', 'own', 'latterly', 'many', 'fifteen', 'whole', 'call', 'also', 'who', 'when', 'not', 'but', 'our', 'more', 'beside', 'moreover', 'ours', 'except', 'its', 'fifty', 'off', 'then', 'wherever', 'whose', 'see', 'first', 'four', 'for', 'something', 'whom', 'must', 'be', 'together', 'on', 'therefore', 'were', 'me', 'cannot', 'just', 'whereas', 'others', 'whence', 'always', 'only', 'do', 'or', 'empty', '’s', 'have', 'my', 'up', 'say', 'again', '’d', 'ca', 'alone', 'being', 'although', 'meanwhile', 'serious', 'they', 'used', 'however', 'hers', 'this', 'the', 'sixty', 'another', 'one', 'whereby', 'via', "'ll", 'really', 'whatever', 'much', 'those', '’m', '’ve', 'hereafter', 'make', 'which', 'no', 'give', 'has', 'into', 'a', 'by', '’ll', 'himself', 'ourselves', 'itself', 'whereafter', "n't", 'same', 'we', 'us', 'since', 'what', 'often', 'someone', 'where', 'out', '‘re', 'other', 'various', 'because', 'never', 'somehow', 'under', 'amount', '‘s', "'d", 'done', 'along', '‘ll', 'anything', 'thus', 'to', 'may', 'sometime', 'become', 'bottom', 'elsewhere', 'below', 'their', 'few', 'am', 'last', '‘m', 'anyway', 'while', 'without', 'whither', 'eleven', 'twenty', 'nothing', 'else', 'former', 'even', 'as', 'made', 'front', 'why', 'thereby', 'name', 'thereupon', '’re', 'does', 'very', 'him', 'at', 'due', 'anyhow', 'third', 'toward', 'should', 'mostly', "'m", 'n‘t', 'seems', 'down', 'beyond', 'had', 'regarding', 'how', 'might', 'afterwards', 'became', 'i', 'can', 'behind', 'against', 'forty', 'show', 'too', 'beforehand', 'twelve', 'either', 'so', 'herein', 'anyone', 'though', 'from', 'hundred', 'until', 'whether', 'yourself', 'sometimes', 'thence', 'next', 'namely', 'once', 'mine', 'per', 'rather', '‘d', 'everything', 'becoming', 'his', 'is', 'somewhere', 'across', 'through', 'indeed', 'full', 'with', 'latter', 'any', 'above', "'s", 'onto', 'please', 'about', 'take', 'herself', 'upon', 'are', 'and', 'neither', 'these', 'during', 'wherein', 'could', 'therein', 'doing', 'whereupon', 'than', 'n’t', 'hence', 'three', 'towards', 'well', 'of', 'hereby', 'further', 'five', 'two', 'within', 'nevertheless', 'move', 'was', 'several', 'go', 'ever', 'some', 'everyone', 'your', 'using', 'perhaps', 'least', 'eight', 'myself', '‘ve', 'whenever', 'put', 'enough', 'nine', 'her', 'them', 'less', 'yours', 'keep', 'seemed', 'almost'}

# %%
punctuations = string.punctuation
print(punctuations)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Creating tokenizer function
def spacy_tokenizer(sentence):
    doc = nlp(sentence)

    mytokens = [ word.lemma_.lower().strip() for word in doc ]


    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    return mytokens

# %%
sentence="I am eating Apple"
spacy_tokenizer(sentence)
# Out:
# ['eat', 'apple']

# %%
count_vector = CountVectorizer(tokenizer = spacy_tokenizer)

# %%
count_vector.fit_transform(["I am eating apple, I like apple","I am playing cricket"]).toarray()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# array([[2, 0, 1, 1, 0],
#        [0, 1, 0, 0, 1]])

# %%
count_vector.get_feature_names_out()
# Out:
# array(['apple', 'cricket', 'eat', 'like', 'play'], dtype=object)

# %%
count_vector.vocabulary_
# Out:
# {'eat': 2, 'apple': 0, 'like': 3, 'play': 4, 'cricket': 1}

# %%
from sklearn.model_selection import train_test_split
X=data['Text']
y=data['IsToxic']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()

# %%
X_train.head()
# Out:
# 101    I wonder what the police expect will happen wh...
# 67     bassem I think walmart is hiring for the holid...
# 541                                 Anybody got a cigar?
# 616           *Monkey screamin bout honkies intensifies*
# 917    5:53 did you see that brick hit that white pig...
# Name: Text, dtype: object

# %%
X_train_vectors=count_vector.fit_transform(X_train)

X_test_vectors=count_vector.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
type(X_train_vectors)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
X_test_vectors.shape
# Out:
# (200, 3153)

# %%
classifier.fit(X_train_vectors,y_train)
# Out:
# LogisticRegression()

# %%
predicted=classifier.predict(X_test_vectors)
print("Logistic Regression Accuracy:",metrics.accuracy_score(y_test, predicted))
print("Logistic Regression Precision:",metrics.precision_score(y_test, predicted))
print("Logistic Regression Recall:",metrics.recall_score(y_test, predicted))
# Out:
# Logistic Regression Accuracy: 0.705
# Logistic Regression Precision: 0.7538461538461538
# Logistic Regression Recall: 0.532608695652174

# %%
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizer)
X_train_vetcors= tfidf_vector.fit_transform(X_train)
X_test_vetcors= tfidf_vector.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
classifier = LogisticRegression()
classifier.fit(X_train_vetcors,y_train)
predicted = classifier.predict(X_test_vetcors)
print("Logistic Regression Accuracy:",metrics.accuracy_score(y_test, predicted))
print("Logistic Regression Precision:",metrics.precision_score(y_test, predicted))
print("Logistic Regression Recall:",metrics.recall_score(y_test, predicted))
# Out:
# Logistic Regression Accuracy: 0.695
# Logistic Regression Precision: 0.746031746031746
# Logistic Regression Recall: 0.5108695652173914
